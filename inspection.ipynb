# %%
import mne
import matplotlib 
import matplotlib.pyplot as plt
# matplotlib.use('Qt5Agg')
from mne.preprocessing import ICA
from mne.preprocessing import read_ica
raw = mne.io.read_raw_fif('rEEG\sub-002\preICA_raw.fif', preload=True)
ica = read_ica(f'rEEG\sub-002\ica-002-variance_compica.fif')
# Out:
# Opening raw data file rEEG\sub-002\preICA_raw.fif...
#     Range : 0 ... 81509 =      0.000 ...   326.036 secs
# Ready.
# Reading 0 ... 81509  =      0.000 ...   326.036 secs...
# Reading c:\Users\User\Documents\EEG_Project\rEEG\sub-002\ica-002-variance_compica.fif ...
# Now restoring ICA solution ...
# Ready.
# C:\Users\User\AppData\Local\Temp\ipykernel_28236\3143805563.py:8: RuntimeWarning: This filename (rEEG\sub-002\ica-002-variance_compica.fif) does not conform to MNE naming conventions. All ICA files should end with -ica.fif, -ica.fif.gz, _ica.fif or _ica.fif.gz
#   ica = read_ica(f'rEEG\sub-002\ica-002-variance_compica.fif')

# %%
figs = ica.plot_components()

for i, fig in enumerate(figs):
    fig.savefig(f"components_{i}_sub001.png", dpi=300)
# Out:
# <MNEFigure size 975x967 with 20 Axes>
# <MNEFigure size 975x967 with 20 Axes>
# <MNEFigure size 975x731.5 with 15 Axes>

# %%
for comp in [1]:
    ica.plot_properties(raw, picks=comp)
# Out:
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 140 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 140 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 140 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 140 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 140 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# ...
