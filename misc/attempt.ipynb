# %%
import mne
import matplotlib
import matplotlib.pyplot as plt
matplotlib.use('Qt5Agg')
# Load a single UCSD EEF file
raw = mne.io.read_raw_bdf('UCSanDiego\sub-hc1\ses-hc\eeg\sub-hc1_ses-hc_task-rest_eeg.bdf', preload=True)
print(raw.info)
print(raw.ch_names)
# preload=True loads data into memory
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       4 matplotlib.use('Qt5Agg')
#       5 # Load a single UCSD EEF file
# ----> 6 raw = mne.io.read_raw_bdf('UCSanDiego\sub-hc1\ses-hc\eeg\sub-hc1_ses-hc_task-rest_eeg.bdf', preload=True)
#       7 print(raw.info)
#       8 print(raw.ch_names)
#
# File c:\Users\User\anaconda3\envs\eeg_ml\Lib\site-packages\mne\io\edf\edf.py:2145, in read_raw_bdf(input_fname, eog, misc, stim_channel, exclude, infer_types, include, preload, units, encoding, exclude_after_unique, verbose)
#    2027 @fill_doc
#    2028 def read_raw_bdf(
#    2029     input_fname,
#    (...)   2041     verbose=None,
#    2042 ) -> RawBDF:
#    2043     """Reader function for BDF files.
#    2044
#    2045     Parameters
#    (...)   2143     encoded in such analog stim channels.
#    2144     """
# ...

# %%
raw.plot(scalings='auto', title='Raw EEG', show=True, block=True)

# Keep only EEG channels
raw.pick(picks='eeg')
# Out:
# C:\Users\User\anaconda3\envs\eeg_ml\Lib\site-packages\mne\viz\utils.py:158: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   (fig or plt).show(**kwargs)

# %%
print(raw.ch_names)
raw.info['bads'] = [raw.ch_names[45], raw.ch_names[4], raw.ch_names[47]]
print(raw.info["bads"])

# %%
psd = raw.compute_psd(fmin=1, fmax=40)  # returns a PSD object

# Plot PSD
psd.plot()

# %%
import numpy as np
data = raw.get_data()
print(data)

# %% [markdown]
# # Preprocessing

# %%
raw.filter(l_freq=1., h_freq=45., fir_design='firwin')

# %%
raw.notch_filter(freqs=60)

# %%
raw.plot(block=True, scalings='auto', title='Inspect EEG for artifacts')
