# %%
import mne
import matplotlib 
import matplotlib.pyplot as plt
matplotlib.use('Qt5Agg')

raw = mne.io.read_raw_fif('rEEG\sub-001\preICA004_raw.fif', preload=True)
raw.plot()
# Out:
# Opening raw data file rEEG\sub-001\preICA004_raw.fif...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 6
#       3 import matplotlib.pyplot as plt
#       4 matplotlib.use('Qt5Agg')
# ----> 6 raw = mne.io.read_raw_fif('rEEG\sub-001\preICA004_raw.fif', preload=True)
#       7 raw.plot()
#
# File c:\Users\User\anaconda3\envs\eeg_ml\Lib\site-packages\mne\io\fiff\raw.py:543, in read_raw_fif(fname, allow_maxshield, preload, on_split_missing, verbose)
#     502 @fill_doc
#     503 def read_raw_fif(
#     504     fname, allow_maxshield=False, preload=False, on_split_missing="raise", verbose=None
#     505 ) -> Raw:
#     506     """Reader function for Raw FIF data.
#     507
#     508     Parameters
#    (...)    541     are updated accordingly.
#     542     """
# --> 543     return Raw(
#     544         fname=fname,
# ...
