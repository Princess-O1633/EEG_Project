# %%
import mne
import matplotlib 
import matplotlib.pyplot as plt
matplotlib.use('Qt5Agg')
from mne.preprocessing import ICA

for i in range(1,4):
    raw = mne.io.read_raw_fif(f'rEEG\\sub-{i:03d}\\preICA_raw.fif', preload=True)

    # Fit ICA with fixed number of components
    ica = ICA(n_components=.9999, method='infomax', random_state=42)
    ica.fit(raw)

    # Save ICA object
    ica.save(f'rEEG/sub-{i:03d}/ica-{i:03d}-variance_compica.fif')
# Out:
# Opening raw data file rEEG\sub-001\preICA_raw.fif...
#     Range : 0 ... 70414 =      0.000 ...   281.656 secs
# Ready.
# Reading 0 ... 70414  =      0.000 ...   281.656 secs...
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 44 components
# Computing Infomax ICA
# Fitting ICA took 129.6s.
# Writing ICA solution to c:\Users\User\Documents\EEG_Project\rEEG\sub-001\ica-001-variance_compica.fif...
# Opening raw data file rEEG\sub-002\preICA_raw.fif...
#     Range : 0 ... 81509 =      0.000 ...   326.036 secs
# Ready.
# C:\Users\User\AppData\Local\Temp\ipykernel_27656\1454934169.py:15: RuntimeWarning: This filename (rEEG/sub-001/ica-001-variance_compica.fif) does not conform to MNE naming conventions. All ICA files should end with -ica.fif, -ica.fif.gz, _ica.fif or _ica.fif.gz
#   ica.save(f'rEEG/sub-{i:03d}/ica-{i:03d}-variance_compica.fif')
# Reading 0 ... 81509  =      0.000 ...   326.036 secs...
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 55 components
# Computing Infomax ICA
# Fitting ICA took 180.5s.
# Writing ICA solution to c:\Users\User\Documents\EEG_Project\rEEG\sub-002\ica-002-variance_compica.fif...
# Opening raw data file rEEG\sub-003\preICA_raw.fif...
#     Range : 0 ... 63089 =      0.000 ...   252.356 secs
# Ready.
# Reading 0 ... 63089  =      0.000 ...   252.356 secs...
# C:\Users\User\AppData\Local\Temp\ipykernel_27656\1454934169.py:15: RuntimeWarning: This filename (rEEG/sub-002/ica-002-variance_compica.fif) does not conform to MNE naming conventions. All ICA files should end with -ica.fif, -ica.fif.gz, _ica.fif or _ica.fif.gz
#   ica.save(f'rEEG/sub-{i:03d}/ica-{i:03d}-variance_compica.fif')
# Fitting ICA to data using 60 channels (please be patient, this may take a while)
# Selecting by explained variance: 43 components
# Computing Infomax ICA
# Fitting ICA took 233.2s.
# Writing ICA solution to c:\Users\User\Documents\EEG_Project\rEEG\sub-003\ica-003-variance_compica.fif...
# C:\Users\User\AppData\Local\Temp\ipykernel_27656\1454934169.py:15: RuntimeWarning: This filename (rEEG/sub-003/ica-003-variance_compica.fif) does not conform to MNE naming conventions. All ICA files should end with -ica.fif, -ica.fif.gz, _ica.fif or _ica.fif.gz
#   ica.save(f'rEEG/sub-{i:03d}/ica-{i:03d}-variance_compica.fif')

# %%
from mne.preprocessing import read_ica

ica = read_ica(f'rEEG\sub-045\ica-045-variance-ica.fif')
# Out:
# Reading c:\Users\User\Documents\EEG_Project\rEEG\sub-045\ica-045-variance-ica.fif ...
# Now restoring ICA solution ...
# Ready.

# %%
plot = ica.plot_components()

# %%
for comp in [0,1,4,5,26]:
    ica.plot_properties(raw, picks=comp)
# Out:
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 64 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 64 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 64 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 64 matching events found
# No baseline correction applied
# 0 projection items activated
#     Using multitaper spectrum estimation with 7 DPSS windows
# Not setting metadata
# 64 matching events found
# No baseline correction applied
# 0 projection items activated
